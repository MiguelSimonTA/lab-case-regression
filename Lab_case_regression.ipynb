# %% [markdown]
# At this point, we have created a model to predict who will make a donation and who won't. But, what about the ammount of money that each person will give?
# In this lab, subset those that made a donation and use that subset to create a model to predict how much money will they give.
#
# Evaluate the result of your model and estimate how much better the result are for the bussiness in comparison with the naive scenario we discuss on Monday.

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline
pd.set_option('display.max_columns', None)

from sklearn.model_selection import train_test_split

# %%
# using the dataset given by the TA
numerical = pd.read_csv(r"C:\Users\Pedro Gomes\Desktop\Filipa_Ironhack\Classes\ML\numerical.csv")
target = pd.read_csv(r"C:\Users\Pedro Gomes\Desktop\Filipa_Ironhack\Classes\ML\target.csv") 
numerical.dtypes
# Out:
# TCODE         int64
# AGE         float64
# INCOME        int64
# WEALTH1       int64
# HIT           int64
#              ...
# AVGGIFT     float64
# CONTROLN      int64
# HPHONE_D      int64
# RFA_2F        int64
# CLUSTER2      int64
# Length: 315, dtype: object

# %%
# Lets check null values in percentage 

nulls_percent_df= numerical.isna().sum()/len(numerical)
nulls_percent_df

# put it in a dataframe 
nulls_percent_df= pd.DataFrame(numerical.isna().sum()/len(numerical))
nulls_percent_df

# Take out of the index 
nulls_percent_df= pd.DataFrame(numerical.isna().sum()/len(numerical)).reset_index()
nulls_percent_df

# Lets change columns name
nulls_percent_df.columns = ['column_name', 'nulls_percentage']
nulls_percent_df

# Lets sort 
nulls_percent_df.sort_values(by = ['nulls_percentage'], ascending = False)


# since there are no null values we dont have to do anything
# Out:
#     column_name  nulls_percentage
# 0         TCODE               0.0
# 207        EIC4               0.0
# 214       EIC11               0.0
# 213       EIC10               0.0
# 212        EIC9               0.0
# ..          ...               ...
# 104       ETHC1               0.0
# 103       HHD12               0.0
# 102       HHD11               0.0
# 101       HHD10               0.0
# 314    CLUSTER2               0.0
#
# [315 rows x 2 columns]

# %%
target = target.drop(['TARGET_B'], axis=1)

# %%
numerical
# Out:
#        TCODE        AGE  INCOME  WEALTH1  HIT  MALEMILI  MALEVET  VIETVETS  \
# 0          0  60.000000       5        9    0         0       39        34
# 1          1  46.000000       6        9   16         0       15        55
# 2          1  61.611649       3        1    2         0       20        29
# 3          0  70.000000       1        4    2         0       23        14
# 4          0  78.000000       3        2   60         1       28         9
# ...      ...        ...     ...      ...  ...       ...      ...       ...
# 95407      1  61.611649       5        9    0        14       36        47
# 95408      1  48.000000       7        9    1         0       31        43
# 95409      1  60.000000       5        9    0         0       18        46
# 95410      0  58.000000       7        9    0         0       28        35
# 95411      2  80.000000       5        8    3         1       33        22
#
# ...

# %%
# define the X and y 

X = numerical
y = target

# Doing the train-test-split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

from sklearn.ensemble import RandomForestRegressor

clf = RandomForestRegressor(n_estimators = 50, max_depth = 7, random_state = 42)
clf.fit(X_train, y_train)

print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))
# Out:
# 0.08947316404751726
# 0.01705376925623925

# %%
from sklearn.model_selection import GridSearchCV
#  Tunning hyperparameters

param_grid = {'n_estimators': [20, 60, 80],
              'max_depth': [2, 4, 8],
              'min_samples_split': [2,4],
              'min_samples_leaf': [1,2]}

clf = RandomForestRegressor(random_state = 42)
grid_search = GridSearchCV(clf, param_grid, cv=2, return_train_score=True, n_jobs = -1 )

grid_search.fit(X_train, y_train)
grid_search.best_params_
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\Users\PEDROG~1\AppData\Local\Temp/ipykernel_18776/3431245583.py in <module>
#      10 grid_search = GridSearchCV(clf, param_grid, cv=2, return_train_score=True, n_jobs = -1 )
#      11
# ---> 12 grid_search.fit(X_train, y_train)
#      13 grid_search.best_params_
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in wrapper(estimator, *args, **kwargs)
#    1150                 )
#    1151             ):
# -> 1152                 return fit_method(estimator, *args, **kwargs)
#    1153
#    1154         return wrapper
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     896                 return results
#     897
# --> 898             self._run_search(evaluate_candidates)
#     899
# ...

# %%
clf = RandomForestRegressor(n_estimators = 60, max_depth = 2, random_state = 42, min_samples_leaf = 2, min_samples_split = 2 )
clf.fit(X_train, y_train)

print(clf.score(X_train, y_train))
print(clf.score(X_test, y_test))

# %%
# dataframe that shows the comparison between the money donated and the predicted values
predictions = pd.DataFrame([y_test, clf.predict(X_test)], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# C:\Users\PEDROG~1\AppData\Local\Temp/ipykernel_18776/1522729194.py in <module>
#       1 # dataframe that shows the comparison between the money donated and the predicted values
# ----> 2 predictions = pd.DataFrame([y_test, clf.predict(X_test)], axis = 1)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     980             The predicted values.
#     981         """
# --> 982         check_is_fitted(self)
#     983         # Check data
#     984         X = self._validate_X_predict(X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1459
#    1460     if not _is_fitted(estimator, attributes, all_or_any):
# -> 1461         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1462
#    1463
#
# ...

# %%
predictions
# Out:
# Empty DataFrame
# Columns: []
# ...
